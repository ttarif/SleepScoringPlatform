# %% [markdown]
# # 02_Visualize_Naps_Features_with_Labels
# this notebook serves as an exploratory analysis of the seal sleep features lined up with labels for Wednesday during a few of her naps
#
# ### Prerequisites:
# - `make features` (this will run `make download` if you have not already downloaded the input files)

# %%
import pandas as pd
import pytz
import datetime

# %%
import sys
sys.path.insert(0, '..')
import src.visualization.visualize as viz

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load features dataframe

# %%
# PST Timezone
pst_timezone = pytz.timezone('America/Los_Angeles')

# Read features and set index as datetimeindex
features_df = pd.read_csv('../data/processed/features/test12_Wednesday_07_features_with_labels.csv',
                          index_col=0)
features_df.index = pd.DatetimeIndex(features_df.index, tz=pst_timezone)
# Out:
# /var/folders/by/vpz_wqc14_vgx3vzwgf90gw00000gn/T/ipykernel_32601/1602631621.py:5: DtypeWarning: Columns (58) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv('../data/processed/features/test12_Wednesday_07_features_with_labels.csv',

# %% [markdown]
# ## Plot Naps

# %% [markdown]
# #### Nap 1

# %%
start_dt = datetime.datetime.strptime('10/25/2019 16:36:00', '%m/%d/%Y %H:%M:%S')\
                    .replace(tzinfo=None).astimezone(pst_timezone)
end_dt = datetime.datetime.strptime('10/25/2019 16:50:00', '%m/%d/%Y %H:%M:%S')\
                    .replace(tzinfo=None).astimezone(pst_timezone)
fig, ax = viz.plot_nap(features_df, 'Simple.Sleep.Code', start_dt, end_dt)

# %% [markdown]
# #### Nap 2

# %%
start_dt = datetime.datetime.strptime('10/25/2019 17:26:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
end_dt = datetime.datetime.strptime('10/25/2019 17:37:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
fig, ax = viz.plot_nap(features_df, 'Simple.Sleep.Code', start_dt, end_dt)

# %% [markdown]
# #### Nap 3

# %%
start_dt = datetime.datetime.strptime('10/25/2019 19:00:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
end_dt = datetime.datetime.strptime('10/25/2019 19:14:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
fig, ax = viz.plot_nap(features_df, 'Simple.Sleep.Code', start_dt, end_dt)

# %% [markdown]
# #### Nap 4

# %%
start_dt = datetime.datetime.strptime('10/25/2019 21:50:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
end_dt = datetime.datetime.strptime('10/25/2019 22:04:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
fig, ax = viz.plot_nap(features_df, 'Simple.Sleep.Code', start_dt, end_dt)
